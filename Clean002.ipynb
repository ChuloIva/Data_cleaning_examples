# %% [markdown]
# <a href="https://colab.research.google.com/github/ChuloIva/Data_cleaning_examples/blob/main/Clean002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ![Capture - Instrumenti dirty.PNG](data:image/png;base64,...)

# %%
df = pd.read_excel(r"C:\Users\icuul\Desktop\Ines\Instrumenti\ODS\Glazba po grupi.ods", engine= "odf")

# Remove rows and collumns that contain all null values.

df.dropna(axis=1, how='all', inplace=True)
df.dropna(axis=0, how='all', inplace=True)

# Remove rows with Strana and ime firme

df = df[~df["Unnamed: 20"].str.contains("Strana:", na=False)]
df = df[~df["Unnamed: 21"].str.contains("Strana:", na=False)]
df = df[~df["Unnamed: 1"].str.contains("REDACTED", na=False)]

# Remove first rows and print description

df = df.drop([df.index[1]])
df = df.drop([df.index[1]])
df = df.drop([df.index[0]])
df = df.drop([df.index[0]])
df = df.drop([df.index[0]])
df = df.drop([df.index[0]])

# Remove naslov i oznake

df = df[~df["Unnamed: 10"].str.contains("PRODAJA I TRENUTNO STANJE PO GRUPAMA ARTIKALA", na=False)]
df = df[~df["Unnamed: 11"].str.contains("PRODAJA I TRENUTNO STANJE PO GRUPAMA ARTIKALA", na=False)]
df = df[~df["Unnamed: 10"].str.contains("PRODAJA", na=False)]
df = df[~df["Unnamed: 10"].str.contains("Iznos bez poreza", na=False)]

# Remove Sveukupno and Ukupno

df = df[~df["Unnamed: 1"].str.contains("SVEUKUPNO:", na=False)]
df = df[~df["Unnamed: 1"].str.contains("Ukupno", na=False)]

# Remove the last column

df.drop(df.tail(0).index,inplace=True)


# Fix the last rows
# Count the number of rows + 4 and reassign

df2 = df.tail(16)
# n of rows --^


# Drop n + 3

df.drop(df.tail(19).index,inplace=True)
# n + 3 --------^


# print(df2)

# Remove rows and collumns in first dataset that contain all null values.

df.dropna(axis=1, how='all', inplace=True)
df.dropna(axis=0, how='all', inplace=True)

# Replace nan with 0

df = df.fillna(0)

# Fix the columns 11 and 10

df["Unnamed: 50"] = df["Unnamed: 11"] + df["Unnamed: 12"]


df = df.drop(columns=["Unnamed: 6", "Unnamed: 11", "Unnamed: 12"], axis=1)
df = df[['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 8', 'Unnamed: 10','Unnamed: 50','Unnamed: 13' ,'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 18', 'Unnamed: 21' ]]

# rename the columns

df.columns = ["Sifra", "Naziv Kategorije", "Kolicina", "MP Vrijednost", "IBP", "ISP", "RUC", "Stanje", "VBP", "VSP"]


# same for the second dataset


# Remove rows and collumns in the second dataset that contain all null values.

df2.dropna(axis=1, how='all', inplace=True)
df2.dropna(axis=0, how='all', inplace=True)

# Drop not needed columns

df2 = df2.drop(columns=["Unnamed: 7"], axis=1)
df2 = df2[['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 9', 'Unnamed: 11','Unnamed: 13','Unnamed: 14' ,'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 19', 'Unnamed: 22' ]]

# rename the columns

df2.columns = ["Sifra", "Naziv Kategorije", "Kolicina", "MP Vrijednost", "IBP", "ISP", "RUC", "Stanje", "VBP", "VSP"]

# Replace nan with 0

df2 = df2.fillna(0)

# Combine the datasets

df3 = pd.concat([df, df2], axis=0)


# Eksport

# df3.to_excel(excel_writer=r"C:\Users\icuul\Desktop\Ines\Data clean\Instrumenti\Glazba po grupi.xlsx" )

# %% [markdown]
# ![Capture - clean instrumenti fo real.PNG](data:image/png;base64,...)

# %% [markdown]
# Not including the original files due to the confidentiality of information. Including before and after png
